# %%
### Pandas
import pandas as pd

### Numpy
import numpy as np

# %%
iris = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data")
print(type(iris))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
### Make copy of iris data frame
df = iris.copy()

# %%
### head() show by default 5 rows, if you mention how many row it will show that much row
df.head(3)
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa

# %%
print(df.shape)
print(df.dtypes)
# Out:
# (149, 5)
# 5.1            float64
# 3.5            float64
# 1.4            float64
# 0.2            float64
# Iris-setosa     object
# dtype: object

# %%
### Change Column header
df.columns = ['sl', 'sw', 'pl', 'pw', 'flower_type']
print(df.columns)
print(df.dtypes)
# Out:
# Index(['sl', 'sw', 'pl', 'pw', 'flower_type'], dtype='object')
# sl             float64
# sw             float64
# pl             float64
# pw             float64
# flower_type     object
# dtype: object

# %%
df.head(3)
# Out:
#     sl   sw   pl   pw  flower_type
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa

# %%
df.describe()
# Out:
#                sl          sw          pl          pw
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
### df.column_name will give you particular column
df.sl
# Out:
# 0      4.9
# 1      4.7
# 2      4.6
# 3      5.0
# 4      5.4
#       ...
# 144    6.7
# 145    6.3
# 146    6.5
# 147    6.2
# 148    5.9
# Name: sl, Length: 149, dtype: float64

# %%
df["flower_type"]
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 144    Iris-virginica
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# Name: flower_type, Length: 149, dtype: object

# %%
df.isnull()
# Out:
#         sl     sw     pl     pw  flower_type
# 0    False  False  False  False        False
# 1    False  False  False  False        False
# 2    False  False  False  False        False
# 3    False  False  False  False        False
# 4    False  False  False  False        False
# ..     ...    ...    ...    ...          ...
# 144  False  False  False  False        False
# 145  False  False  False  False        False
# 146  False  False  False  False        False
# 147  False  False  False  False        False
# 148  False  False  False  False        False
#
# [149 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sl             0
# sw             0
# pl             0
# pw             0
# flower_type    0
# dtype: int64

# %%
## Access data slices
df.iloc[1:4, 2:4]
# Out:
#     pl   pw
# 1  1.3  0.2
# 2  1.5  0.2
# 3  1.4  0.2

# %%
df.tail()
# Out:
#       sl   sw   pl   pw     flower_type
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica

# %%
df.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %% [markdown]
# ### Remove Row from data set use .drop()

# %%
df.drop(0)
df.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
### df.drop() doesn't remove inplace, it make a copy excluding row
a = df.drop(0)
a.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa

# %%
### Inplace remove df.drop(0, inplace=True)
df.drop(0, inplace=True)
df.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa

# %% [markdown]
# ### Difference between label and position

# %%
df.drop(0, inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df.drop(0, inplace=True)
#       2 df.head()
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5249 def drop(  # type: ignore[override]
#    5250     self,
#    (...)
# ...

# %%
df.drop(3, inplace=True)
df.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa
# 6  5.0  3.4  1.5  0.2  Iris-setosa

# %%
df.columns
# Out:
# Index(['sl', 'sw', 'pl', 'pw', 'flower_type'], dtype='object')

# %%
df.index
# Out:
# Int64Index([  1,   2,   4,   5,   6,   7,   8,   9,  10,  11,
#             ...
#             139, 140, 141, 142, 143, 144, 145, 146, 147, 148],
#            dtype='int64', length=147)

# %%
### label of index 0
df.index[0], df.index[3]
# Out:
# (1, 5)

# %%
## Remove row by position
df.drop(df.index[0], inplace=True)
df.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa
# 6  5.0  3.4  1.5  0.2  Iris-setosa
# 7  4.4  2.9  1.4  0.2  Iris-setosa

# %%
df.index[[0,1]]
# Out:
# Int64Index([2, 4], dtype='int64')

# %%
df.sl > 5
# Out:
# 2      False
# 4       True
# 5      False
# 6      False
# 7      False
#        ...
# 144     True
# 145     True
# 146     True
# 147     True
# 148     True
# Name: sl, Length: 146, dtype: bool

# %%
df[df.sl > 7]
# Out:
#       sl   sw   pl   pw     flower_type
# 101  7.1  3.0  5.9  2.1  Iris-virginica
# 104  7.6  3.0  6.6  2.1  Iris-virginica
# 106  7.3  2.9  6.3  1.8  Iris-virginica
# 108  7.2  3.6  6.1  2.5  Iris-virginica
# 116  7.7  3.8  6.7  2.2  Iris-virginica
# 117  7.7  2.6  6.9  2.3  Iris-virginica
# 121  7.7  2.8  6.7  2.0  Iris-virginica
# 124  7.2  3.2  6.0  1.8  Iris-virginica
# 128  7.2  3.0  5.8  1.6  Iris-virginica
# 129  7.4  2.8  6.1  1.9  Iris-virginica
# 130  7.9  3.8  6.4  2.0  Iris-virginica
# 134  7.7  3.0  6.1  2.3  Iris-virginica

# %%
df[df.flower_type == 'Iris-setosa']
# Out:
#      sl   sw   pl   pw  flower_type
# 2   4.6  3.1  1.5  0.2  Iris-setosa
# 4   5.4  3.9  1.7  0.4  Iris-setosa
# 5   4.6  3.4  1.4  0.3  Iris-setosa
# 6   5.0  3.4  1.5  0.2  Iris-setosa
# 7   4.4  2.9  1.4  0.2  Iris-setosa
# 8   4.9  3.1  1.5  0.1  Iris-setosa
# 9   5.4  3.7  1.5  0.2  Iris-setosa
# 10  4.8  3.4  1.6  0.2  Iris-setosa
# 11  4.8  3.0  1.4  0.1  Iris-setosa
# 12  4.3  3.0  1.1  0.1  Iris-setosa
# 13  5.8  4.0  1.2  0.2  Iris-setosa
# 14  5.7  4.4  1.5  0.4  Iris-setosa
# 15  5.4  3.9  1.3  0.4  Iris-setosa
# 16  5.1  3.5  1.4  0.3  Iris-setosa
# 17  5.7  3.8  1.7  0.3  Iris-setosa
# 18  5.1  3.8  1.5  0.3  Iris-setosa
# 19  5.4  3.4  1.7  0.2  Iris-setosa
# 20  5.1  3.7  1.5  0.4  Iris-setosa
# 21  4.6  3.6  1.0  0.2  Iris-setosa
# 22  5.1  3.3  1.7  0.5  Iris-setosa
# 23  4.8  3.4  1.9  0.2  Iris-setosa
# 24  5.0  3.0  1.6  0.2  Iris-setosa
# 25  5.0  3.4  1.6  0.4  Iris-setosa
# 26  5.2  3.5  1.5  0.2  Iris-setosa
# 27  5.2  3.4  1.4  0.2  Iris-setosa
# ...

# %%
df[df.flower_type == 'Iris-setosa'].describe()
# Out:
#               sl         sw         pl         pw
# count  46.000000  46.000000  46.000000  46.000000
# mean    5.013043   3.426087   1.471739   0.247826
# std     0.364301   0.390120   0.178466   0.111034
# min     4.300000   2.300000   1.000000   0.100000
# 25%     4.800000   3.125000   1.400000   0.200000
# 50%     5.000000   3.400000   1.500000   0.200000
# 75%     5.200000   3.700000   1.600000   0.300000
# max     5.800000   4.400000   1.900000   0.600000

# %% [markdown]
# #### iloc[] doing by position and loc[] is doing by label

# %%
### Add a row
print( df.head() )
print( df.iloc[0] )
# Out:
#     sl   sw   pl   pw  flower_type
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa
# 6  5.0  3.4  1.5  0.2  Iris-setosa
# 7  4.4  2.9  1.4  0.2  Iris-setosa
# sl                     4.6
# sw                     3.1
# pl                     1.5
# pw                     0.2
# flower_type    Iris-setosa
# Name: 2, dtype: object

# %%
df.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.loc[8]
# Out:
# sl                     4.9
# sw                     3.1
# pl                     1.5
# pw                     0.1
# flower_type    Iris-setosa
# Name: 8, dtype: object

# %%
### add a row  we add a row at end.
df.loc[0] = [1,2,3,4,"Iris-setosa"]

# %%
df.tail()
# Out:
#       sl   sw   pl   pw     flower_type
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
# 0    1.0  2.0  3.0  4.0     Iris-setosa

# %%
df.index
# Out:
# Int64Index([  2,   4,   5,   6,   7,   8,   9,  10,  11,  12,
#             ...
#             140, 141, 142, 143, 144, 145, 146, 147, 148,   0],
#            dtype='int64', length=147)

# %%
### Reset Index
df.reset_index()
# Out:
#      index   sl   sw   pl   pw     flower_type
# 0        2  4.6  3.1  1.5  0.2     Iris-setosa
# 1        4  5.4  3.9  1.7  0.4     Iris-setosa
# 2        5  4.6  3.4  1.4  0.3     Iris-setosa
# 3        6  5.0  3.4  1.5  0.2     Iris-setosa
# 4        7  4.4  2.9  1.4  0.2     Iris-setosa
# ..     ...  ...  ...  ...  ...             ...
# 142    145  6.3  2.5  5.0  1.9  Iris-virginica
# 143    146  6.5  3.0  5.2  2.0  Iris-virginica
# 144    147  6.2  3.4  5.4  2.3  Iris-virginica
# 145    148  5.9  3.0  5.1  1.8  Iris-virginica
# 146      0  1.0  2.0  3.0  4.0     Iris-setosa
#
# [147 rows x 6 columns]

# %%
### Problem in reset_index() is add a new column index, but we don't want so we pass drop = true
df.reset_index(drop = True)
# Out:
#       sl   sw   pl   pw     flower_type
# 0    4.6  3.1  1.5  0.2     Iris-setosa
# 1    5.4  3.9  1.7  0.4     Iris-setosa
# 2    4.6  3.4  1.4  0.3     Iris-setosa
# 3    5.0  3.4  1.5  0.2     Iris-setosa
# 4    4.4  2.9  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 142  6.3  2.5  5.0  1.9  Iris-virginica
# 143  6.5  3.0  5.2  2.0  Iris-virginica
# 144  6.2  3.4  5.4  2.3  Iris-virginica
# 145  5.9  3.0  5.1  1.8  Iris-virginica
# 146  1.0  2.0  3.0  4.0     Iris-setosa
#
# [147 rows x 5 columns]

# %%
### Reset index at inplace so pass inplace = true
df.reset_index(drop = True, inplace= True)
df.index
# Out:
# RangeIndex(start=0, stop=147, step=1)

# %%
 ### Remove column
 df.drop('sl')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 2
#       1 ### Remove column
# ----> 2 df.drop('sl')
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5249 def drop(  # type: ignore[override]
#    5250     self,
#    (...)
# ...

# %%
 ### Remove column
 df.drop('sl', axis=1)
# Out:
#       sw   pl   pw     flower_type
# 0    3.1  1.5  0.2     Iris-setosa
# 1    3.9  1.7  0.4     Iris-setosa
# 2    3.4  1.4  0.3     Iris-setosa
# 3    3.4  1.5  0.2     Iris-setosa
# 4    2.9  1.4  0.2     Iris-setosa
# ..   ...  ...  ...             ...
# 142  2.5  5.0  1.9  Iris-virginica
# 143  3.0  5.2  2.0  Iris-virginica
# 144  3.4  5.4  2.3  Iris-virginica
# 145  3.0  5.1  1.8  Iris-virginica
# 146  2.0  3.0  4.0     Iris-setosa
#
# [147 rows x 4 columns]

# %%
 ### Remove column inplace
 df.drop('sl', axis=1, inplace=True)

# %%
df.describe()
# Out:
#                sw          pl          pw
# count  147.000000  147.000000  147.000000
# mean     3.039456    3.818367    1.244898
# std      0.442372    1.738328    0.786546
# min      2.000000    1.000000    0.100000
# 25%      2.800000    1.600000    0.350000
# 50%      3.000000    4.400000    1.300000
# 75%      3.300000    5.100000    1.800000
# max      4.400000    6.900000    4.000000

# %%
### one more way to delete is del
del df['sw']

# %%
df.describe()
# Out:
#                pl          pw
# count  147.000000  147.000000
# mean     3.818367    1.244898
# std      1.738328    0.786546
# min      1.000000    0.100000
# 25%      1.600000    0.350000
# 50%      4.400000    1.300000
# 75%      5.100000    1.800000
# max      6.900000    4.000000

# %%
df.head
# Out:
# <bound method NDFrame.head of       pl   pw     flower_type
# 0    1.5  0.2     Iris-setosa
# 1    1.7  0.4     Iris-setosa
# 2    1.4  0.3     Iris-setosa
# 3    1.5  0.2     Iris-setosa
# 4    1.4  0.2     Iris-setosa
# ..   ...  ...             ...
# 142  5.0  1.9  Iris-virginica
# 143  5.2  2.0  Iris-virginica
# 144  5.4  2.3  Iris-virginica
# 145  5.1  1.8  Iris-virginica
# 146  3.0  4.0     Iris-setosa
#
# [147 rows x 3 columns]>

# %%
df = iris.copy()
df.columns = ['sl', 'sw', 'pl', 'pw', 'flower_type']
df.describe()
# Out:
#                sl          sw          pl          pw
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
### add a column
df["diff_pl_pw"] = df["pl"] - df["pw"]
df.tail()
# Out:
#       sl   sw   pl   pw     flower_type  diff_pl_pw
# 144  6.7  3.0  5.2  2.3  Iris-virginica         2.9
# 145  6.3  2.5  5.0  1.9  Iris-virginica         3.1
# 146  6.5  3.0  5.2  2.0  Iris-virginica         3.2
# 147  6.2  3.4  5.4  2.3  Iris-virginica         3.1
# 148  5.9  3.0  5.1  1.8  Iris-virginica         3.3

# %% [markdown]
# ### Handling NAN

# %%
df.iloc[2:4, 1:3] = 0
df.head()
# Out:
#     sl   sw   pl   pw  flower_type  diff_pl_pw
# 0  4.9  3.0  1.4  0.2  Iris-setosa         1.2
# 1  4.7  3.2  1.3  0.2  Iris-setosa         1.1
# 2  4.6  0.0  0.0  0.2  Iris-setosa         1.3
# 3  5.0  0.0  0.0  0.2  Iris-setosa         1.2
# 4  5.4  3.9  1.7  0.4  Iris-setosa         1.3

# %%
df.iloc[2:4, 1:3] = np.nan
df.head()
# Out:
#     sl   sw   pl   pw  flower_type  diff_pl_pw
# 0  4.9  3.0  1.4  0.2  Iris-setosa         1.2
# 1  4.7  3.2  1.3  0.2  Iris-setosa         1.1
# 2  4.6  NaN  NaN  0.2  Iris-setosa         1.3
# 3  5.0  NaN  NaN  0.2  Iris-setosa         1.2
# 4  5.4  3.9  1.7  0.4  Iris-setosa         1.3

# %%
df.describe()
# Out:
#                sl          sw          pl          pw  diff_pl_pw
# count  149.000000  147.000000  147.000000  149.000000  149.000000
# mean     5.848322    3.046939    3.806122    1.205369    2.569128
# std      0.828594    0.434048    1.750351    0.761292    1.047707
# min      4.300000    2.000000    1.000000    0.100000    0.800000
# 25%      5.100000    2.800000    1.600000    0.300000    1.400000
# 50%      5.800000    3.000000    4.400000    1.300000    2.900000
# 75%      6.400000    3.300000    5.100000    1.800000    3.300000
# max      7.900000    4.400000    6.900000    2.500000    4.700000

# %%
### drop NAN data
df.dropna()
# Out:
#       sl   sw   pl   pw     flower_type  diff_pl_pw
# 0    4.9  3.0  1.4  0.2     Iris-setosa         1.2
# 1    4.7  3.2  1.3  0.2     Iris-setosa         1.1
# 4    5.4  3.9  1.7  0.4     Iris-setosa         1.3
# 5    4.6  3.4  1.4  0.3     Iris-setosa         1.1
# 6    5.0  3.4  1.5  0.2     Iris-setosa         1.3
# ..   ...  ...  ...  ...             ...         ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica         2.9
# 145  6.3  2.5  5.0  1.9  Iris-virginica         3.1
# 146  6.5  3.0  5.2  2.0  Iris-virginica         3.2
# 147  6.2  3.4  5.4  2.3  Iris-virginica         3.1
# 148  5.9  3.0  5.1  1.8  Iris-virginica         3.3
#
# [147 rows x 6 columns]

# %%
### drop NAN data inplace
df.dropna(inplace=True)
df.head()
# Out:
#     sl   sw   pl   pw  flower_type  diff_pl_pw
# 0  4.9  3.0  1.4  0.2  Iris-setosa         1.2
# 1  4.7  3.2  1.3  0.2  Iris-setosa         1.1
# 4  5.4  3.9  1.7  0.4  Iris-setosa         1.3
# 5  4.6  3.4  1.4  0.3  Iris-setosa         1.1
# 6  5.0  3.4  1.5  0.2  Iris-setosa         1.3

# %%
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#     sl   sw   pl   pw  flower_type  diff_pl_pw
# 0  4.9  3.0  1.4  0.2  Iris-setosa         1.2
# 1  4.7  3.2  1.3  0.2  Iris-setosa         1.1
# 2  5.4  3.9  1.7  0.4  Iris-setosa         1.3
# 3  4.6  3.4  1.4  0.3  Iris-setosa         1.1
# 4  5.0  3.4  1.5  0.2  Iris-setosa         1.3

# %%
df.iloc[2:4, 1:3] = np.nan
df.head()
# Out:
#     sl   sw   pl   pw  flower_type  diff_pl_pw
# 0  4.9  3.0  1.4  0.2  Iris-setosa         1.2
# 1  4.7  3.2  1.3  0.2  Iris-setosa         1.1
# 2  5.4  NaN  NaN  0.4  Iris-setosa         1.3
# 3  4.6  NaN  NaN  0.3  Iris-setosa         1.1
# 4  5.0  3.4  1.5  0.2  Iris-setosa         1.3

# %%
### fill NAN entries
df.sw.fillna(df.sw.mean(), inplace=True)
df.head()
# Out:
#     sl        sw   pl   pw  flower_type  diff_pl_pw
# 0  4.9  3.000000  1.4  0.2  Iris-setosa         1.2
# 1  4.7  3.200000  1.3  0.2  Iris-setosa         1.1
# 2  5.4  3.038621  NaN  0.4  Iris-setosa         1.3
# 3  4.6  3.038621  NaN  0.3  Iris-setosa         1.1
# 4  5.0  3.400000  1.5  0.2  Iris-setosa         1.3

# %%
df.pl.fillna(df.pl.mean(), inplace=True)
df.head()
# Out:
#     sl        sw        pl   pw  flower_type  diff_pl_pw
# 0  4.9  3.000000  1.400000  0.2  Iris-setosa         1.2
# 1  4.7  3.200000  1.300000  0.2  Iris-setosa         1.1
# 2  5.4  3.038621  3.837241  0.4  Iris-setosa         1.3
# 3  4.6  3.038621  3.837241  0.3  Iris-setosa         1.1
# 4  5.0  3.400000  1.500000  0.2  Iris-setosa         1.3

# %% [markdown]
# ### Fill NAN with mean of particular flower type
# a = df[df.flower_type == 'Iris-setosa']
# a.pl.mean()
#
# OR
#
# df.fillna(df[df.flower_type == 'Iris-setosa'].pl.mean(), inplace=True)

# %% [markdown]
# ## Handel String Based Data

# %%
df['Gender'] = 'Female'
df.head()
# Out:
#     sl        sw        pl   pw  flower_type  diff_pl_pw  Gender
# 0  4.9  3.000000  1.400000  0.2  Iris-setosa         1.2  Female
# 1  4.7  3.200000  1.300000  0.2  Iris-setosa         1.1  Female
# 2  5.4  3.038621  3.837241  0.4  Iris-setosa         1.3  Female
# 3  4.6  3.038621  3.837241  0.3  Iris-setosa         1.1  Female
# 4  5.0  3.400000  1.500000  0.2  Iris-setosa         1.3  Female

# %%
df.iloc[0:16, 6] = 'Male'
df.head()
# Out:
#     sl        sw        pl   pw  flower_type  diff_pl_pw Gender
# 0  4.9  3.000000  1.400000  0.2  Iris-setosa         1.2   Male
# 1  4.7  3.200000  1.300000  0.2  Iris-setosa         1.1   Male
# 2  5.4  3.038621  3.837241  0.4  Iris-setosa         1.3   Male
# 3  4.6  3.038621  3.837241  0.3  Iris-setosa         1.1   Male
# 4  5.0  3.400000  1.500000  0.2  Iris-setosa         1.3   Male

# %%
def func(s):
    if s == 'Male':
        return 0
    else:
        return 1
    
df['sex'] = df.Gender.apply(func)
df.head()
# Out:
#     sl        sw        pl   pw  flower_type  diff_pl_pw Gender  sex
# 0  4.9  3.000000  1.400000  0.2  Iris-setosa         1.2   Male    0
# 1  4.7  3.200000  1.300000  0.2  Iris-setosa         1.1   Male    0
# 2  5.4  3.038621  3.837241  0.4  Iris-setosa         1.3   Male    0
# 3  4.6  3.038621  3.837241  0.3  Iris-setosa         1.1   Male    0
# 4  5.0  3.400000  1.500000  0.2  Iris-setosa         1.3   Male    0

# %%
del df['Gender']
df.head()
# Out:
#     sl        sw        pl   pw  flower_type  diff_pl_pw  sex
# 0  4.9  3.000000  1.400000  0.2  Iris-setosa         1.2    0
# 1  4.7  3.200000  1.300000  0.2  Iris-setosa         1.1    0
# 2  5.4  3.038621  3.837241  0.4  Iris-setosa         1.3    0
# 3  4.6  3.038621  3.837241  0.3  Iris-setosa         1.1    0
# 4  5.0  3.400000  1.500000  0.2  Iris-setosa         1.3    0
